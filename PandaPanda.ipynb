# %%
import pandas
import matplotlib.pyplot as plt
df=pandas.read_csv("datasets/monthly_births_by_state.csv")
df.head()
# Out:
#      State  Year     Month  Provisional Number of Live Births
# 0  ALABAMA  2016   January                               4816
# 1  ALABAMA  2016  February                               4690
# 2  ALABAMA  2016     March                               4847
# 3  ALABAMA  2016     April                               4536
# 4  ALABAMA  2016       May                               4789

# %%
df.groupby('State')['Provisional Number of Live Births'].mean().plot()
plt.show()
